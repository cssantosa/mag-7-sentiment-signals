# %%
import pandas as pd
from pathlib import Path
import sys
ROOT = Path.cwd().resolve()
if (ROOT / "src" / "scrapers").exists():
    pass
elif (ROOT.parent / "src" / "scrapers").exists():
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
from scripts.database import get_connection

conn = get_connection()
df = pd.read_sql("SELECT * FROM sentiment_scores ORDER BY fetched_at", conn)
conn.close()
print(df.shape)
print(df.head())
# Out:
# (5, 14)
#    id             posted_at            fetched_at  \
# 0   1  2026-02-26T14:00:00Z  2026-02-26T15:43:31Z
# 1   2  2026-02-26T14:00:00Z  2026-02-26T15:43:31Z
# 2   3  2026-02-26T14:00:00Z  2026-02-26T15:43:31Z
# 3   4  2026-02-26T12:00:00Z  2026-02-26T15:43:31Z
# 4   5  2026-02-25T23:49:19Z  2026-02-26T15:43:31Z
#
#                                             headline  \
# 0  Figma partners with OpenAI to bake in support ...
# 1  Figma partners with OpenAI to bake in support ...
# 2  Figma partners with OpenAI to bake in support ...
# 3  Instagram now alerts parents if their teen sea...
# 4  Anthropic acquires computer-use AI startup Ver...
#
#                                                  url      source    reporter  \
# 0  https://techcrunch.com/2026/02/26/figma-partne...  TechCrunch  TechCrunch
# 1  https://techcrunch.com/2026/02/26/figma-partne...  TechCrunch  TechCrunch
# 2  https://techcrunch.com/2026/02/26/figma-partne...  TechCrunch  TechCrunch
# ...

# %%
from scripts.database import load_sentiment_df

df = load_sentiment_df()
df.dtypes  # posted_at, fetched_at are datetime64
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from scripts.database import load_sentiment_df
#       3 df = load_sentiment_df()
#       4 df.dtypes  # posted_at, fetched_at are datetime64
#
# ImportError: cannot import name 'load_sentiment_df' from 'scripts.database' (C:\Users\Christian Santosa\Python\mag-7-sentiment-signals\scripts\database.py)

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 from scripts.database import load_sentiment_df
#       3 df = load_sentiment_df()
#       4 df.dtypes  # posted_at, fetched_at are datetime64
#
# ImportError: cannot import name 'load_sentiment_df' from 'scripts.database' (C:\Users\Christian Santosa\Python\mag-7-sentiment-signals\scripts\database.py)
